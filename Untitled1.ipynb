# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import lightgbm as lgb

# %%
data = pd.read_csv("train.csv", encoding ='big5')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (17,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    CUS_ID GENDER AGE CHARGE_CITY_CD CONTACT_CITY_CD  EDUCATION_CD  \
# 0    3418      M   低             A1              A1           NaN
# 1    4302      M   低             A1              A1           NaN
# 2    5545      M   低             A1              A1           1.0
# 3    7207      M   低             A1              A1           NaN
# 4    7213      M   低             A1              A1           1.0
#
#    MARRIAGE_CD LAST_A_CCONTACT_DT  L1YR_A_ISSUE_CNT LAST_A_ISSUE_DT  ...  \
# 0          NaN                  Y                 0               N  ...
# 1          NaN                  Y                 0               N  ...
# 2          0.0                  Y                 1               Y  ...
# 3          0.0                  Y                 0               N  ...
# 4          0.0                  N                 0               N  ...
#
#    L1YR_GROSS_PRE_AMT CUST_9_SEGMENTS_CD  FINANCETOOLS_A  FINANCETOOLS_B  \
# 0            0.000174                  C             NaN             NaN
# 1            0.008724                  A             NaN             NaN
# 2            0.005359                  A               Y               N
# 3            0.000000                  C             NaN             NaN
# 4            0.000603                  C             NaN             NaN
#
#    FINANCETOOLS_C  FINANCETOOLS_D  FINANCETOOLS_E FINANCETOOLS_F  \
# 0             NaN             NaN             NaN            NaN
# 1             NaN             NaN             NaN            NaN
# 2               N               N               N              N
# 3             NaN             NaN             NaN            NaN
# 4             NaN             NaN             NaN            NaN
#
#   FINANCETOOLS_G Y1
# 0            NaN  N
# 1            NaN  N
# 2              N  N
# 3            NaN  N
# 4            NaN  N
#
# [5 rows x 132 columns]

# %%
data.describe()
# Out:
#              CUS_ID  EDUCATION_CD   MARRIAGE_CD  L1YR_A_ISSUE_CNT  \
# count  1.000000e+05  79438.000000  92049.000000     100000.000000
# mean   1.267299e+06      2.169075      0.315289          0.118170
# std    7.382534e+05      0.929452      0.489678          0.561755
# min    1.200000e+01      1.000000      0.000000          0.000000
# 25%    6.275398e+05      1.000000      0.000000          0.000000
# 50%    1.261358e+06      2.000000      0.000000          0.000000
# 75%    1.903561e+06      3.000000      1.000000          0.000000
# max    2.551470e+06      4.000000      2.000000         22.000000
#
#        L1YR_B_ISSUE_CNT  CHANNEL_A_POL_CNT  CHANNEL_B_POL_CNT  \
# count     100000.000000      100000.000000      100000.000000
# mean           0.003330           1.627730           0.031080
# std            0.062442           3.365798           0.262326
# min            0.000000           0.000000           0.000000
# 25%            0.000000           0.000000           0.000000
# 50%            0.000000           0.000000           0.000000
# 75%            0.000000           2.000000           0.000000
# max            4.000000          97.000000          17.000000
#
#        OCCUPATION_CLASS_CD        APC_CNT       INSD_CNT  ...  \
# count         96040.000000  100000.000000  100000.000000  ...
# mean              1.304967       0.681070       0.283620  ...
# std               0.711769       0.614847       0.747238  ...
# min               0.000000       0.000000       0.000000  ...
# 25%               1.000000       0.000000       0.000000  ...
# 50%               1.000000       1.000000       0.000000  ...
# 75%               1.000000       1.000000       0.000000  ...
# max               6.000000       4.000000      19.000000  ...
#
#        OUTPATIENT_SURGERY_AMT  INPATIENT_SURGERY_AMT  PAY_LIMIT_MED_MISC_AMT  \
# count            72460.000000           72460.000000            72460.000000
# mean                 0.089922               0.058821                0.094473
# std                  0.101751               0.078278                0.166933
# min                  0.000000               0.000000                0.000000
# 25%                  0.000000               0.000000                0.000000
# 50%                  0.063492               0.030303                0.000000
# 75%                  0.142857               0.103030                0.312500
# max                  0.952381               0.824242                1.000000
#
#        FIRST_CANCER_AMT  ILL_ACCELERATION_AMT  ILL_ADDITIONAL_AMT  \
# count      72460.000000          72460.000000        72460.000000
# mean           0.014284              0.004284            0.002229
# std            0.033439              0.014163            0.009714
# min            0.000000              0.000000            0.000000
# 25%            0.000000              0.000000            0.000000
# 50%            0.000000              0.000000            0.000000
# 75%            0.018868              0.000000            0.000000
# max            0.734591              0.666667            0.300000
#
#        LONG_TERM_CARE_AMT  MONTHLY_CARE_AMT  LIFE_INSD_CNT  L1YR_GROSS_PRE_AMT
# count        72460.000000      72460.000000  100000.000000       100000.000000
# mean             0.002394          0.018912       0.031473            0.000525
# std              0.020305          0.040821       0.034269            0.003117
# min              0.000000          0.000000       0.000000            0.000000
# 25%              0.000000          0.000000       0.015625            0.000000
# 50%              0.000000          0.000000       0.015625            0.000000
# 75%              0.000000          0.025773       0.046875            0.000265
# max              0.809524          0.859107       0.921875            0.327815
#
# [8 rows x 42 columns]

# %%
data.drop(['CUS_ID','GENDER','CHARGE_CITY_CD','EDUCATION_CD',
              'MARRIAGE_CD','A_IND','B_IND','C_IND'],axis=1,inplace=True)

# %%
#Checking missing values
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
         # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
# Missing values statistics
missing_values = missing_values_table(data)
missing_values
# Out:
# Your selected dataframe has 124 columns.
# There are 67 columns that have missing values.
#                         Missing Values  % of Total Values
# L1YR_C_CNT                       87936               87.9
# FINANCETOOLS_G                   62641               62.6
# FINANCETOOLS_A                   62641               62.6
# FINANCETOOLS_B                   62641               62.6
# FINANCETOOLS_D                   62641               62.6
# FINANCETOOLS_E                   62641               62.6
# FINANCETOOLS_C                   62641               62.6
# FINANCETOOLS_F                   62641               62.6
# ANNUAL_PREMIUM_AMT               62445               62.4
# IF_ADD_INSD_G_IND                51848               51.8
# IF_ADD_INSD_R_IND                51848               51.8
# IF_ADD_INSD_F_IND                51848               51.8
# IF_ADD_INSD_L_IND                51848               51.8
# IF_ADD_INSD_Q_IND                51848               51.8
# LEVEL                            43305               43.3
# RFM_R                            43294               43.3
# APC_1ST_AGE                      43282               43.3
# RFM_M_LEVEL                      43282               43.3
# APC_1ST_YEARDIF                  43282               43.3
# TERMINATION_RATE                 43282               43.3
# REBUY_TIMES_CNT                  43282               43.3
# ANNUAL_INCOME_AMT                39201               39.2
# OUTPATIENT_SURGERY_AMT           27540               27.5
# MONTHLY_CARE_AMT                 27540               27.5
# LONG_TERM_CARE_AMT               27540               27.5
# ILL_ADDITIONAL_AMT               27540               27.5
# FIRST_CANCER_AMT                 27540               27.5
# PAY_LIMIT_MED_MISC_AMT           27540               27.5
# INPATIENT_SURGERY_AMT            27540               27.5
# ILL_ACCELERATION_AMT             27540               27.5
# ...                                ...                ...
# IF_ISSUE_INSD_I_IND              20083               20.1
# IF_ISSUE_INSD_Q_IND              20083               20.1
# IF_ISSUE_INSD_P_IND              20083               20.1
# IF_ISSUE_INSD_O_IND              20083               20.1
# IF_ISSUE_INSD_N_IND              20083               20.1
# IF_ISSUE_INSD_M_IND              20083               20.1
# IF_ISSUE_INSD_K_IND              20083               20.1
# IF_ISSUE_INSD_J_IND              20083               20.1
# IF_ISSUE_INSD_L_IND              20083               20.1
# IF_ISSUE_INSD_H_IND              20083               20.1
# IF_ISSUE_INSD_G_IND              20083               20.1
# IF_ISSUE_INSD_F_IND              20083               20.1
# IF_ISSUE_INSD_E_IND              20083               20.1
# IF_ISSUE_INSD_D_IND              20083               20.1
# IF_ISSUE_INSD_C_IND              20083               20.1
# IF_ISSUE_INSD_B_IND              20083               20.1
# IF_ISSUE_INSD_A_IND              20083               20.1
# BMI                              16645               16.6
# OCCUPATION_CLASS_CD               3960                4.0
# IF_ADD_INSD_IND                    171                0.2
# INSD_LAST_YEARDIF_CNT              171                0.2
# INSD_1ST_AGE                       171                0.2
# X_G_IND                             38                0.0
# X_E_IND                             38                0.0
# X_D_IND                             38                0.0
# X_C_IND                             38                0.0
# X_B_IND                             38                0.0
# X_A_IND                             38                0.0
# X_H_IND                             38                0.0
# X_F_IND                             38                0.0
#
# [67 rows x 2 columns]

# %%
#lets do Lable enconding coding to make more features 

le = LabelEncoder()
le_count = 0

# Iterate through the columns
for col in data:
    if data[col].dtype == 'object':
        # If 2 or fewer unique categories
        if len(list(data[col].unique())) <= 2:
            # Train on the training data
            le.fit(data[col])
            # Transform both training and testing data
            data[col] = le.transform(data[col])
            
            
            # Keep track of how many columns were label encoded
            le_count += 1
            
print('%d columns were label encoded.' % le_count)
# Out:
# 39 columns were label encoded.

# %%
#data = pd.get_dummies(data)
#print('Training Features shape: ', data.shape)
sns.set(style="white")

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(data.corr(), cmap=cmap, vmax=.3, center=0,annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
colum_name =[]
unique_value=[]
# Iterate through the columns
for col in data:
    if data[col].dtype == 'object':
        # If 2 or fewer unique categories
        colum_name.append(str(col)) 
        unique_value.append(data[col].nunique())
table= pd.DataFrame()
table['Col_name'] = colum_name
table['Value']= unique_value
            
table=table.sort_values('Value',ascending=False)
table
# Out:
#                Col_name  Value
# 38   CUST_9_SEGMENTS_CD      8
# 1       CONTACT_CITY_CD      8
# 4                 RFM_R      4
# 5       REBUY_TIMES_CNT      4
# 0                   AGE      4
# 3          INSD_1ST_AGE      4
# 2           APC_1ST_AGE      4
# 6              LIFE_CNT      3
# 35    IF_ADD_INSD_G_IND      2
# 28  IF_ISSUE_INSD_N_IND      2
# 29  IF_ISSUE_INSD_O_IND      2
# 30  IF_ISSUE_INSD_P_IND      2
# 31  IF_ISSUE_INSD_Q_IND      2
# 32    IF_ADD_INSD_F_IND      2
# 33    IF_ADD_INSD_L_IND      2
# 34    IF_ADD_INSD_Q_IND      2
# 36    IF_ADD_INSD_R_IND      2
# 37      IF_ADD_INSD_IND      2
# 26  IF_ISSUE_INSD_L_IND      2
# 39       FINANCETOOLS_A      2
# 40       FINANCETOOLS_B      2
# 41       FINANCETOOLS_C      2
# 42       FINANCETOOLS_D      2
# 43       FINANCETOOLS_E      2
# 44       FINANCETOOLS_F      2
# 27  IF_ISSUE_INSD_M_IND      2
# 23  IF_ISSUE_INSD_I_IND      2
# 25  IF_ISSUE_INSD_K_IND      2
# 14              X_H_IND      2
# 7               X_A_IND      2
# 8               X_B_IND      2
# 9               X_C_IND      2
# 10              X_D_IND      2
# 11              X_E_IND      2
# 12              X_F_IND      2
# 13              X_G_IND      2
# 15  IF_ISSUE_INSD_A_IND      2
# 24  IF_ISSUE_INSD_J_IND      2
# 16  IF_ISSUE_INSD_B_IND      2
# 17  IF_ISSUE_INSD_C_IND      2
# 18  IF_ISSUE_INSD_D_IND      2
# 19  IF_ISSUE_INSD_E_IND      2
# 20  IF_ISSUE_INSD_F_IND      2
# 21  IF_ISSUE_INSD_G_IND      2
# 22  IF_ISSUE_INSD_H_IND      2
# 45       FINANCETOOLS_G      2

# %%
f, ax = plt.subplots(figsize=(20, 20))
sns.countplot(x='insured_hobbies',hue='fraud_reported',data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c5d7e15ca520> in <module>
#       1 f, ax = plt.subplots(figsize=(20, 20))
# ----> 2 sns.countplot(x='insured_hobbies',hue='fraud_reported',data=data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'insured_hobbies'
